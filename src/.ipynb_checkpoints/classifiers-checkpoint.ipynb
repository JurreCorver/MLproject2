# %%
# classifiers
import os, glob
import csv
import matplotlib.pyplot as plt
import numpy as np
from numpy import genfromtxt
import nibabel as nib


# csv write a formated csv file
def csvFormatedOutput(fileName, ans):
    with open(fileName, 'w', newline='') as f:
        c = csv.writer(f, delimiter=',',
                       quotechar='|', quoting=csv.QUOTE_MINIMAL)
        c.writerow(['ID', 'Prediction'])
        for i in range(0, len(ans)):
#             temp = listToMat()
            c.writerow([i + 1, ans[i]])
    return 0

def listToMat(l):
    return np.array(l).reshape(-1, np.array(l).shape[-1])

def plotter(measured, predicted):
    # plot the result
    fig, ax = plt.subplots()
    y = measured
    ax.scatter(y, predicted)
    ax.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=4)
    ax.set_xlabel('Measured')
    ax.set_ylabel('Predicted')
    plt.show()
    return 0
def DimRedPlot(x,y):
    plt.figure()
    colors = ['navy', 'turquoise']
    labelName = ['bad', 'good']
    lw = 2
    # y= np.reshape(trainingTargets,[-1,])
    for color, i, label in zip(colors, [0, 1], labelName):
        plt.scatter(x[y == bin(i), 0], 
                    x[(y) == bin(i), 1], 
                    color=color, alpha=.8, lw=lw, label=label)
    plt.legend(loc='best', shadow=False, scatterpoints=1)    
    plt.show()
    return 0
def calibrationProb(classifier, X, y, test):
    caliClassifier = CalibratedClassifierCV(classifier, cv=10, method='isotonic')
    caliClassifier.fit(X, y)
    preTest = caliClassifier.predict(test)
    probTest = caliClassifier.predict_proba(test)
    return preTest,probTest[:,1]
def searchClassifier(baseClassifier, paraGrid, X, y):
    clf = GridSearchCV(baseClassifier, paraGrid, cv =10, 
                   scoring=make_scorer(metrics.accuracy_score))
    clf = clf.fit(X, np.reshape(y,[-1,]))
    return clf.best_estimator_

# %%
# load training and test data
# read the training targets
trainTarget = '../data/targets.csv'
temp = []
temp.append(genfromtxt(trainTarget, delimiter=','))
trainingTemp = (listToMat(temp)).T
temp = []
for i in range(trainingTemp.shape[0]):
    temp.append(bin(int(trainingTemp[i])))
trainingTargets = listToMat(temp).T

# read the training features
trainFeature = '../trainFeature.csv'
temp = []
temp.append(genfromtxt(trainFeature, delimiter=','))
trainingFeatures = (listToMat(temp)).T

# read the testing features
testFeature = '../testFeature.csv'
temp = []
temp.append(genfromtxt(testFeature, delimiter=','))
testingFeatures = (listToMat(temp)).T

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.calibration import CalibratedClassifierCV

#SGD classifier
sgdClassifier = SGDClassifier(loss = 'hinge', penalty='l1', n_iter=1000)
caliClassifier = CalibratedClassifierCV(sgdClassifier, cv=10, method='isotonic')
caliClassifier.fit(trainingFeatures, trainingTargets)
preTest= caliClassifier.predict(testingFeatures)
probTest = caliClassifier.predict_proba(testingFeatures)
# csvFormatedOutput('../sgdL1PredictedProb.csv', probTest[:,0])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
csvFormatedOutput('../sgdL1PredictedProb.csv', probTest[:,1])
# Out:
# 0

# %%
# svm
from sklearn.svm import SVC, NuSVC, LinearSVC
from sklearn.covariance import MinCovDet
# covEstimator = MinCovDet(store_precision=True, assume_centered=True)
# robCov = covEstimator.fit(trainingFeatures)
# # svc
# svc = SVC(C=1.0, kernel='rbf', degree=3, gamma=robCov, probability=True, max_iter=-1)
# svc.fit(trainingFeatures, trainingTargets)
# preClass = svc.predict(trainingFeatures)
# prob = svc.predict_proba(trainingFeatures)
# probTest = svc.predict_proba(testingFeatures)
# preTestClass = svc.predict(testingFeatures)
# csvFormatedOutput('../svcPredictedProb.csv',probTest)

# %%
# linear svc
linearSvc = LinearSVC(penalty='l2', max_iter=2000, dual=False)
# linearSvc.fit(trainingFeatures, trainingTargets)
caliClassifier = CalibratedClassifierCV(linearSvc, cv = 10, method = 'sigmoid')
caliClassifier.fit(trainingFeatures, trainingTargets)
probTest = caliClassifier.predict_proba(testingFeatures)
preTestClass = caliClassifier.predict(testingFeatures)
csvFormatedOutput('../linearSvcPredictedProb.csv',probTest[:,1])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0

# %%
# mlp+ calibration
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(30), activation='logistic', 
                    learning_rate='adaptive', solver='lbfgs', max_iter=2000)
caliClassifier = CalibratedClassifierCV(mlp, cv = 10, method = 'isotonic')
caliClassifier.fit(trainingFeatures, trainingTargets)
probTest = caliClassifier.predict_proba(testingFeatures)
preTestClass = caliClassifier.predict(testingFeatures)
# csvFormatedOutput('../mlpPredictedProb.csv',probTest[:,1])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
csvFormatedOutput('../mlpPredictedProb.csv',probTest[:,1])
# Out:
# 0

# %%
# naive bayesian
from sklearn.naive_bayes import GaussianNB
naiveBayes = GaussianNB()
naiveBayes.fit(trainingFeatures, trainingTargets)
trainProb = naiveBayes.predict_proba(trainingFeatures)
trainClass = naiveBayes.predict(trainingFeatures)
testClass = naiveBayes.predict(testingFeatures)
testProb = naiveBayes.predict_proba(testingFeatures)
# csvFormatedOutput('../navieBayesPredictedProb.csv',testProb[:,1])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0

# %%
# neighbors
from sklearn.neighbors import RadiusNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier

# knn
knnClf = KNeighborsClassifier(n_neighbors=8,weights='distance',p=2)
knnClf.fit(trainingFeatures, trainingTargets)
trainClass = knnClf.predict(trainingFeatures)
trainProb = knnClf.predict_proba(trainingFeatures)
testClass = knnClf.predict(testingFeatures)
testProb = knnClf.predict_proba(testingFeatures)
csvFormatedOutput('../knnPredictedProb.csv',testProb[:,1])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/ipykernel/__main__.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# 0

# %%
# discriminant analysis
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import log_loss

ldaClf = LinearDiscriminantAnalysis(shrinkage='auto',solver='eigen',n_components=2)
# ldaClf.fit(trainingFeatures, trainingTargets)
# trainClass = ldaClf.predict(trainingFeatures)
# trainProb = ldaClf.predict_proba(trainingFeatures)
# trainAccuracy = ldaClf.score(trainingFeatures, trainingTargets)
# trainLoss = log_loss(trainingTargets, trainProb[:,1])
# testClass = ldaClf.predict(testingFeatures)
# testProb = ldaClf.predict_proba(testingFeatures)
# csvFormatedOutput('../ldaPredictedProb_1.csv',testProb[:,1])

caliClassifier = CalibratedClassifierCV(ldaClf, cv = 10, method = 'isotonic')
caliClassifier.fit(trainingFeatures, trainingTargets)
probTest = caliClassifier.predict_proba(testingFeatures)
preTestClass = caliClassifier.predict(testingFeatures)
csvFormatedOutput('../ldaCVPredictedProb_2.csv',probTest[:,1])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0

# %%
# lda + grid search
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import log_loss
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.model_selection import train_test_split

# split data
X_train, X_test, y_train, y_test = train_test_split(
    trainingFeatures, trainingTargets, test_size=0.25, random_state=42)

# define scorer
logScorer = make_scorer(log_loss, needs_proba=True)

param_grid = {'n_components': [1,2,4,6,10,15,20,30,40,50,60],}
clf = GridSearchCV(LinearDiscriminantAnalysis(shrinkage='auto',solver='eigen'), param_grid, 
                   cv =10, scoring=logScorer)
clf = clf.fit(X_train, np.reshape(y_train,[-1,]))

clfBest = clf.best_estimator_
clfBest.fit(trainingFeatures, trainingTargets)
testClass = clfBest.predict(testingFeatures)
testProb = clfBest.predict_proba(testingFeatures)
csvFormatedOutput('../ldaGridCVPredictedProb.csv',testProb[:,1])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0

# %%
clfBest
# Out:
# LinearDiscriminantAnalysis(n_components=1, priors=None, shrinkage='auto',
#               solver='eigen', store_covariance=False, tol=0.0001)

# %%
# SVC + grid search cv
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.metrics import make_scorer
from sklearn.metrics import log_loss

# split data
X_train, X_test, y_train, y_test = train_test_split(
    trainingFeatures, trainingTargets, test_size=0.25, random_state=42)

# define scorer
logScorer = make_scorer(log_loss, needs_proba=True)

# pca
n_components = 20
pca = PCA(n_components=n_components, svd_solver='randomized',
          whiten=True).fit(X_train)
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)
param_grid = {'C': [1e3, 5e3, 1e4, 5e4, 1e5],
              'gamma': [0.0001, 0.0005, 0.001, 0.005, 0.01, 0.1], }
# param_grid = {'C': [1e3],
#               'gamma': [0.0001], }
clf = GridSearchCV(SVC(kernel='rbf', class_weight='balanced',probability=True), param_grid, 
                   cv =10, scoring=logScorer)
clf = clf.fit(X_train_pca, np.reshape(y_train,[-1,]))

# # evaluation
clfBest = clf.best_estimator_
clfBest.fit(trainingFeatures, trainingTargets)
testClass = clfBest.predict(testingFeatures)
testProb = clfBest.predict_proba(testingFeatures)
csvFormatedOutput('../svcPredictedProb.csv',testProb[:,1])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0

# %%
# perceptron + cross val score
from sklearn.model_selection import cross_val_score,cross_val_predict
from sklearn.metrics import make_scorer
from sklearn.metrics import log_loss
from sklearn.linear_model import Perceptron
from sklearn.calibration import CalibratedClassifierCV
from sklearn.decomposition import PCA

# define scorer
clf = Perceptron(penalty='l1',n_iter=500)
# clf.fit(trainingFeatures, trainingTargets)
caliClassifier = CalibratedClassifierCV(clf, cv = 10, method = 'isotonic')
caliClassifier.fit(trainingFeatures, trainingTargets)
probTest = caliClassifier.predict_proba(testingFeatures)
preTestClass = caliClassifier.predict(testingFeatures)
csvFormatedOutput('../perceptronCVPredictedProb.csv',probTest[:,1])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# plot the result of pca
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn import (manifold, decomposition, ensemble,
                     discriminant_analysis, random_projection)

# pca
# n_components = 2
# pca = PCA(n_components=n_components, svd_solver='randomized',
#           whiten=True).fit(trainingFeatures)
# trainingFeaturesPCA = pca.transform(trainingFeatures)
# DimRedPlot(trainingFeaturesPCA, np.reshape(trainingTargets,[-1]))

# comparison
# pca
X = trainingFeatures
y = np.reshape(trainingTargets, [-1,])
X_pca = decomposition.TruncatedSVD(n_components=2).fit_transform(X)
DimRedPlot(X_pca, y)

# lda
X2 = X.copy()
X2.flat[::X.shape[1] + 1] += 0.01  # Make X invertible
# t0 = time()
X_lda = discriminant_analysis.LinearDiscriminantAnalysis(n_components=2).fit_transform(X2, y)
DimRedPlot(X_lda, y)

# isomap
n_neighbors = 30
X_iso = manifold.Isomap(n_neighbors, n_components=2).fit_transform(X)
DimRedPlot(X_iso, y)

# lle
clf = manifold.LocallyLinearEmbedding(n_neighbors, n_components=2,
                                      method='standard')
X_lle = clf.fit_transform(X)
DimRedPlot(X_lle, y)

# # mlle
# clf = manifold.LocallyLinearEmbedding(n_neighbors, n_components=2,
#                                       method='modified')
# X_mlle = clf.fit_transform(X)
# DimRedPlot(X_mlle, y)

# # hlle
# clf = manifold.LocallyLinearEmbedding(n_neighbors, n_components=2,
#                                       method='hessian')
# X_hlle = clf.fit_transform(X)
# DimRedPlot(X_hlle, y)

# # ltsa
# clf = manifold.LocallyLinearEmbedding(n_neighbors, n_components=2,
#                                       method='ltsa')
# X_ltsa = clf.fit_transform(X)
# DimRedPlot(X_ltsa, y)

# MDS  embedding of the digits dataset
clf = manifold.MDS(n_components=2, n_init=1, max_iter=1000)
X_mds = clf.fit_transform(X)
DimRedPlot(X_mds, y)

# random forest
hasher = ensemble.RandomTreesEmbedding(n_estimators=200, random_state=0,
                                       max_depth=5)
X_transformed = hasher.fit_transform(X)
pca = decomposition.TruncatedSVD(n_components=2)
X_reduced = pca.fit_transform(X_transformed)
DimRedPlot(X_reduced, y)

# spectral
embedder = manifold.SpectralEmbedding(n_components=2, random_state=0,
                                      eigen_solver="arpack")
X_se = embedder.fit_transform(X)
DimRedPlot(X_se, y)
# t sne
tsne = manifold.TSNE(n_components=2, init='pca', random_state=0)
X_tsne = tsne.fit_transform(X)
DimRedPlot(X_tsne, y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/sklearn/discriminant_analysis.py:389: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# 0

# %%
# lda + cal CV
X = trainingFeatures
y = np.reshape(trainingTargets, [-1,])

# lda
X2 = X.copy()
X2.flat[::X.shape[1] + 1] += 0.01  # Make X invertible
ldaClf = discriminant_analysis.LinearDiscriminantAnalysis(n_components=2, 
                                                          solver='eigen', shrinkage='auto')
ldaClf.fit(X2,y)
X_lda = ldaClf.fit_transform(X2, y)
DimRedPlot(X_lda, y)

caliClassifier = CalibratedClassifierCV(ldaClf, cv = 10, method = 'isotonic')
caliClassifier.fit(X2, trainingTargets)
probTest = caliClassifier.predict_proba(testingFeatures)
preTestClass = caliClassifier.predict(testingFeatures)
# csvFormatedOutput('../ldaCVPredictedProb.csv',probTest[:,1])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
csvFormatedOutput('../ldaCVPredictedProb.csv',probTest[:,1])
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.metrics import make_scorer
from sklearn.metrics import log_loss
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.calibration import CalibratedClassifierCV

#SGD classifier
# sgdClassifier = SGDClassifier(loss = 'hinge', penalty='l1', n_iter=1000)
# caliClassifier = CalibratedClassifierCV(sgdClassifier, cv=10, method='isotonic')
# caliClassifier.fit(trainingFeatures, trainingTargets)
# preTest= caliClassifier.predict(testingFeatures)
# probTest = caliClassifier.predict_proba(testingFeatures)
# csvFormatedOutput('../sgdL1PredictedProb.csv', probTest[:,1])


# define scorer
# logScorer = make_scorer(log_loss, needs_proba=True)
# find the best sgd by Grid search CV
param_grid = {'loss': ['hinge', 'log', 'modified_huber', 'squared_hinge', 'perceptron'],
              'penalty': ['l1','l2'], 
             'alpha': [0.00001,0.0001,0.001,0.01,0.1]}
clf = GridSearchCV(SGDClassifier(n_iter=1000), param_grid, 
                   cv =10, scoring=make_scorer(metrics.accuracy_score))
clf = clf.fit(trainingFeatures, np.reshape(trainingTargets,[-1,]))

# Adaboost of the best one

# %%
sgdBest = clf.best_estimator_
# caliClassifier = CalibratedClassifierCV(sgdBest, cv=10, method='isotonic')
# caliClassifier.fit(trainingFeatures, trainingTargets)
# preTest= caliClassifier.predict(testingFeatures)
# probTest = caliClassifier.predict_proba(testingFeatures)
sgdPreTest, sgdProbTest = calibrationProb(sgdBest, trainingFeatures, trainingTargets,
                                         testingFeatures)
# csvFormatedOutput('../sgdBestPredictedProb.csv', probTest[:,1])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
sgdBest
# Out:
# SGDClassifier(alpha=0.1, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='squared_hinge', n_iter=1000,
#        n_jobs=1, penalty='l1', power_t=0.5, random_state=None,
#        shuffle=True, verbose=0, warm_start=False)

# %%
# decision tree test
from sklearn.tree import DecisionTreeClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.metrics import make_scorer
from sklearn.metrics import log_loss

# logScorer = make_scorer(log_loss, needs_proba=True)


paraGrid = {'criterion': ['gini','entropy'],
            'max_leaf_nodes': [2,3,4]}
decisionTreeClf = DecisionTreeClassifier(random_state= 42)
decisionTreeBest = searchClassifier(decisionTreeClf, paraGrid, 
                                   trainingFeatures, trainingTargets)
dtPreTest, dtProbTest = calibrationProb(decisionTreeBest, trainingFeatures, trainingTargets,
                                         testingFeatures)
dtProbTest
# csvFormatedOutput('../decisionTreeBestPredictedProb.csv', dtProbTest)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/sklearn/utils/validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([ 0.93543062,  0.46700579,  0.93543062,  0.46700579,  0.46700579,
#         0.43835082,  0.93543062,  0.93543062,  0.93543062,  0.93543062,
#         0.93543062,  0.93543062,  0.85374535,  0.93543062,  0.93543062,
#         0.93543062,  0.93543062,  0.38532051,  0.38532051,  0.38532051,
#         0.46700579,  0.93543062,  0.93543062,  0.46700579,  0.38532051,
#         0.93543062,  0.38532051,  0.93543062,  0.93543062,  0.93543062,
#         0.38532051,  0.93543062,  0.93543062,  0.93543062,  0.93543062,
#         0.93543062,  0.38532051,  0.38532051,  0.93543062,  0.51203503,
#         0.85374535,  0.38532051,  0.38532051,  0.46700579,  0.46700579,
# ...

# %%
decisionTreeBest
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=2, min_impurity_split=1e-07,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=42,
#             splitter='best')

# %%
# adaBoost + sgd best + grid search
from sklearn.ensemble import AdaBoostClassifier
baseClassifier = sgdBest
adaParaGrid = {'n_estimators': [10,50,100,200],
              'learning_rate':[0.001,0.01,0.1,0.5,1],
              'algorithm': ['SAMME']}
ada = AdaBoostClassifier(base_estimator=baseClassifier, random_state=0)
adaBest = searchClassifier(ada, adaParaGrid, trainingFeatures, trainingTargets)
adaPreTest,adaProbTest = calibrationProb(adaBest, trainingFeatures, trainingTargets,
                                         testingFeatures)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-344-95b86c8f3a42> in <module>()
#       6               'algorithm': ['SAMME']}
#       7 ada = AdaBoostClassifier(base_estimator=baseClassifier, random_state=0)
# ----> 8 adaBest = searchClassifier(ada, adaParaGrid, trainingFeatures, trainingTargets)
#       9 adaPreTest,adaProbTest = calibrationProb(adaBest, trainingFeatures, trainingTargets,
#      10                                          testingFeatures)
#
# <ipython-input-334-b608483d9fb1> in searchClassifier(baseClassifier, paraGrid, X, y)
#      54     clf = GridSearchCV(baseClassifier, paraGrid, cv =10,
#      55                    scoring=make_scorer(metrics.accuracy_score))
# ---> 56     clf = clf.fit(X, np.reshape(y,[-1,]))
#      57     return clf.best_estimator_
#
# ...

# %%
csvFormatedOutput('../adaSGDBestPredictedProb.csv', adaProbTest)

# %%
# bagging + sgd best + grid search
baseClassifier = sgdBest
baggingParaGrid = {'n_estimators': [10, 50, 100, 200]}
bagging = BaggingClassifier(base_estimator=baseClassifier, max_features=1.0, max_samples=1.0)
baggingBest = searchClassifier(bagging, baggingParaGrid, trainingFeatures, trainingTargets)
baggingPreTest, baggingProbTest = calibrationProb(baggingBest,
                                                  trainingFeatures, trainingTargets, testingFeatures)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-343-f0af6bf1f9c8> in <module>()
#       3 baggingParaGrid = {'n_estimators': [10, 50, 100, 200]}
#       4 bagging = BaggingClassifier(base_estimator=baseClassifier, max_features=1.0, max_samples=1.0)
# ----> 5 baggingBest = searchClassifier(bagging, baggingParaGrid, trainingFeatures, trainingTargets)
#       6 baggingPreTest, baggingProbTest = calibrationProb(baggingBest,
#       7                                                   trainingFeatures, trainingTargets, testingFeatures)
#
# <ipython-input-334-b608483d9fb1> in searchClassifier(baseClassifier, paraGrid, X, y)
#      54     clf = GridSearchCV(baseClassifier, paraGrid, cv =10,
#      55                    scoring=make_scorer(metrics.accuracy_score))
# ---> 56     clf = clf.fit(X, np.reshape(y,[-1,]))
#      57     return clf.best_estimator_
#
# ...

# %%
csvFormatedOutput('../baggingSGDBestPredictedProb.csv', baggingProbTest)
